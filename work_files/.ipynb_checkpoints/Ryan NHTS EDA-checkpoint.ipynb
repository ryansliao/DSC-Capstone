# %% [markdown]
# # NHTS Vehicle Type EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vehicles = pd.read_csv("vehpub_2017.csv")
households = pd.read_csv("hhpub_2017.csv")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
vehicles = vehicles.merge(households[['HOUSEID', 'CNTTDHH', 'CAR', 'PRICE', 'PLACE']], on='HOUSEID', how='left')

# %%
vehicles['VEHTYPE'] = vehicles['VEHTYPE'].replace(5, 4)
vehicles['FUELTYPE'] = vehicles['FUELTYPE'].replace(6, 4)
vehicles = vehicles[(vehicles['VEHTYPE'] > 0)
                    & (vehicles['VEHTYPE'] != 6)
                    & (vehicles['VEHTYPE'] != 97)
                    & (vehicles['FUELTYPE'] > 0)
                    & (vehicles['FUELTYPE'] != 97)
                    & (vehicles['VEHAGE'] > 0)
                    & (vehicles['CAR'] > 0)
                    & (vehicles['PRICE'] > 0)
                    & (vehicles['PLACE'] > 0)
                    & (vehicles['BESTMILE'] != -9)
                    & (vehicles['HTPPOPDN'] != -9)
                    & (vehicles['GSYRGAL'] != -9)
                    & (vehicles['URBRUR'] == 1)]
vehicles.loc[vehicles['VEHTYPE'] == 1, 'VEHTYPE'] = "Automobile"
vehicles.loc[vehicles['VEHTYPE'] == 2, 'VEHTYPE'] = "Van"
vehicles.loc[vehicles['VEHTYPE'] == 3, 'VEHTYPE'] = "SUV"
vehicles.loc[vehicles['VEHTYPE'] == 4, 'VEHTYPE'] = "Truck"
vehicles.loc[vehicles['VEHTYPE'] == 7, 'VEHTYPE'] = "Motorcycle"
vehicles.loc[vehicles['FUELTYPE'] == 1, 'FUELTYPE'] = "Gas"
vehicles.loc[vehicles['FUELTYPE'] == 2, 'FUELTYPE'] = "Diesel"
vehicles.loc[vehicles['FUELTYPE'] == 3, 'FUELTYPE'] = "Hybrid"
vehicles.head(10)
# Out:
#      HOUSEID  VEHID  VEHYEAR  VEHAGE MAKE  MODEL FUELTYPE     VEHTYPE  \
# 0   30000007      1     2007      10   49  49032      Gas  Automobile
# 1   30000007      2     2004      13   49  49442      Gas         Van
# 2   30000007      3     1998      19   19  19014      Gas  Automobile
# 3   30000007      4     1997      20   19  19021      Gas  Automobile
# 4   30000007      5     1993      24   20  20481      Gas       Truck
# 9   30000012      1     2011       6   58  58037      Gas  Automobile
# 10  30000012      2     2004      13   12  12473      Gas         SUV
# 11  30000019      1     2006      11   37  37032      Gas  Automobile
# 12  30000019      2     1997      20   21  21001      Gas  Automobile
# 13  30000029      1     2016       1   49  49402      Gas         SUV
#
#     WHOMAIN  OD_READ  HFUEL  VEHOWNED  VEHOWNMO  ANNMILES  HYBRID  PERSONID  \
# 0         3    69000     -1         1        -1      1000       2         3
# 1        -8   164000     -1         1        -1      2500       2        -8
# 2         1   120000     -1         1        -1       900       2         1
# 3         2      -88     -1         1        -1       500       2         2
# 4         2   300000     -1         1        -1     10000       2         2
# 9         1    70115     -1         1        -1     11000       2         1
# 10        1    68204     -1         1        -1      6000       2         1
# 11        1   120000     -1         1        -1     10000       2         1
# 12        1   135000     -1         1        -1      5000       2         1
# 13        1     8774     -1         2         5     21058       2         1
#
#     TRAVDAY  HOMEOWN  HHSIZE  HHVEHCNT  HHFAMINC  DRVRCNT HHSTATE  HHSTFIPS  \
# 0         2        1       3         5         7        3      NC        37
# 1         2        1       3         5         7        3      NC        37
# 2         2        1       3         5         7        3      NC        37
# 3         2        1       3         5         7        3      NC        37
# 4         2        1       3         5         7        3      NC        37
# 9         5        1       1         2        10        1      NY        36
# 10        5        1       1         2        10        1      NY        36
# 11        5        1       2         2         3        2      MD        24
# 12        5        1       2         2         3        2      MD        24
# 13        3        1       2         2         5        2      WI        55
#
#     NUMADLT  WRKCOUNT  TDAYDATE  LIF_CYC  MSACAT  MSASIZE  RAIL  URBAN  \
# 0         3         1    201608       10       3        1     2      1
# 1         3         1    201608       10       3        1     2      1
# 2         3         1    201608       10       3        1     2      1
# 3         3         1    201608       10       3        1     2      1
# 4         3         1    201608       10       3        1     2      1
# 9         1         1    201607        1       3        3     2      1
# 10        1         1    201607        1       3        3     2      1
# 11        2         0    201605        2       3        2     2      1
# 12        2         0    201605        2       3        2     2      1
# 13        2         0    201610       10       3        3     2      1
#
#     URBANSIZE  URBRUR  CENSUS_D  CENSUS_R  CDIVMSAR  HH_RACE  HH_HISP HH_CBSA  \
# 0           1       1         5         3        53        2        2   XXXXX
# 1           1       1         5         3        53        2        2   XXXXX
# 2           1       1         5         3        53        2        2   XXXXX
# 3           1       1         5         3        53        2        2   XXXXX
# 4           1       1         5         3        53        2        2   XXXXX
# 9           3       1         2         1        23        1        2   XXXXX
# 10          3       1         2         1        23        1        2   XXXXX
# 11          1       1         5         3        53        1        2   XXXXX
# 12          1       1         5         3        53        1        2   XXXXX
# 13          2       1         3         2        33        1        2   XXXXX
#
#     SMPLSRCE     WTHHFIN      BESTMILE  BEST_FLG  BEST_EDT  BEST_OUT HBHUR  \
# 0          2  187.314320  14611.926637         1        -1         4     T
# 1          2  187.314320   4767.090946         3        -1        -1     T
# 2          2  187.314320   8000.324552         1        -1        -1     T
# 3          2  187.314320    725.932347         2        -1        -1     T
# 4          2  187.314320  12437.658757         1        -1        -1     T
# 9          2   79.419586   4616.917047         1        -1        -1     C
# 10         2   79.419586   4002.551052         1        -1        -1     C
# 11         2  279.143588   7027.686033         1        -1        -1     S
# 12         2  279.143588  12833.557760         1        -1        -1     S
# 13         2  103.240304  14029.079480         1        -1        -1     S
#
#     HTHTNRNT  HTPPOPDN  HTRESDN  HTEEMPDN  HBHTNRNT  HBPPOPDN  HBRESDN  \
# 0         50      1500      750       750        20       750      300
# 1         50      1500      750       750        20       750      300
# 2         50      1500      750       750        20       750      300
# 3         50      1500      750       750        20       750      300
# 4         50      1500      750       750        20       750      300
# 9         80     17000    17000      5000        60     17000     7000
# 10        80     17000    17000      5000        60     17000     7000
# 11        40       300      300       150        50       750      300
# 12        40       300      300       150        50       750      300
# 13        40      1500      750       750        40      1500      750
#
#        GSYRGAL     GSTOTCST  FEGEMPG  FEGEMPGA    GSCOST  FEGEMPGF  CNTTDHH_x  \
# 0   487.064221  1126.457778       30        -9  2.312750         1          6
# 1   250.899523   580.267873       19        -9  2.312750         1          6
# 2   444.462475  1027.930589       18        -9  2.312750         1          6
# 3    40.329575    93.272224       18        -9  2.312750         1          6
# 4   888.404197  2054.656806       14        -9  2.312750         1          6
# 9   219.853193   542.011404       21        -9  2.465333         1          9
# 10  250.159441   616.726408       16        -9  2.465333         1          9
# 11  305.551567   745.596748       23        -9  2.440167         1          4
# 12  641.677888  1565.800993       20        -9  2.440167         1          4
# 13  561.163179  1271.876346       25        -9  2.266500         1         10
#
#     CNTTDHH_y  CAR  PRICE  PLACE
# 0           6    1      1      2
# 1           6    1      1      2
# 2           6    1      1      2
# 3           6    1      1      2
# 4           6    1      1      2
# 9           9    1      2      1
# 10          9    1      2      1
# 11          4    1      2      3
# 12          4    1      2      3
# 13         10    1      3      2

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)

# %%
sns.catplot(data=vehicles[vehicles['VEHAGE'] >= 0], kind='count', x='VEHAGE', aspect=3)

# %% [markdown]
# Pretty steady increase in vehicle data year by year with a couple of exceptions. There seems to be a big gap between 1977 and 1985, with an unusually high amount of cars registered in 1977. Vehicle ownership seems to have gone down in 2009 post financial crisis as well.

# %%
temp = vehicles.groupby(["HTPPOPDN", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("HTPPOPDN").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='HTPPOPDN,HTPPOPDN'>

# %%
temp = vehicles.groupby(["MSACAT", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("MSACAT").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='MSACAT,MSACAT'>

# %%
temp = vehicles.groupby(["MSASIZE", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("MSASIZE").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='MSASIZE,MSASIZE'>

# %%
temp = vehicles.groupby(["NUMADLT", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("NUMADLT").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='NUMADLT,NUMADLT'>

# %%
temp = vehicles.groupby(["HHVEHCNT", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("HHVEHCNT").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='HHVEHCNT,HHVEHCNT'>

# %%
temp = vehicles.groupby(["HHFAMINC", "VEHTYPE"]).count()["HOUSEID"].drop([-9, -8, -7])
temp.groupby("HHFAMINC").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='HHFAMINC,HHFAMINC'>

# %%
temp = vehicles.groupby(["HBHUR", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("HBHUR").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='HBHUR,HBHUR'>

# %%
temp = vehicles.groupby(["LIF_CYC", "VEHTYPE"]).count()["HOUSEID"].drop(-9)
temp.groupby("LIF_CYC").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='LIF_CYC,LIF_CYC'>

# %%
temp = vehicles.groupby(["CDIVMSAR", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("CDIVMSAR").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='CDIVMSAR,CDIVMSAR'>

# %%
temp = vehicles.groupby(["HHSTFIPS", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("HHSTFIPS").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='HHSTFIPS,HHSTFIPS'>

# %%
temp = vehicles.groupby(["CENSUS_D", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("CENSUS_D").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='CENSUS_D,CENSUS_D'>

# %%
temp = vehicles.groupby(["CENSUS_R", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("CENSUS_R").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='CENSUS_R,CENSUS_R'>

# %%
temp = vehicles.groupby(["CNTTDHH", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("CNTTDHH").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='CNTTDHH,CNTTDHH'>

# %%
temp = vehicles.groupby(["CAR", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("CAR").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='CAR,CAR'>

# %%
temp = vehicles.groupby(["PRICE", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("PRICE").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='PRICE,PRICE'>

# %%
temp = vehicles.groupby(["PLACE", "VEHTYPE"]).count()["HOUSEID"]
temp.groupby("PLACE").apply(lambda x: x / float(x.sum())).unstack().plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='PLACE,PLACE'>

# %%
nums = np.arange(1, 11).tolist()
df = vehicles[vehicles['LIF_CYC'].isin(nums)]
df['LIF_CYC'] = df['LIF_CYC'].replace({1: '1 Adult, 0 Child',
                2: '2+ Adult, 0 Child',
                3: '1 Adult, Youngest 0-5',
                4: '2+ Adult, Youngest 0-5',
                5: '1 Adult, Youngest 6-15',
                6: '2+ Adult, Youngest 6-15',
                7: '1 Adult, Youngest 16-21',
                8: '2+ Adult, Youngest 16-21',
                9: '1 Adult Retired, 0 Child',
                10: '2+ Adult Retired, 0 Child'})
sns.catplot(data=df, kind='count', x='LIF_CYC', aspect=4)
# Out:
# /tmp/ipykernel_598/2200526936.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LIF_CYC'] = df['LIF_CYC'].replace({1: '1 Adult, 0 Child',

# %% [markdown]
# LIF_CYC - Life Cycle classification for the household, derived by attributes pertaining to age, relationship, and work status.

# %%
nums = [-9]
df = vehicles[~vehicles['HTRESDN'].isin(nums)]
sns.catplot(data=df, kind='count', x='HTRESDN', aspect=2)

# %% [markdown]
# HTRESDN - Category of housing units per square mile in the census tract of the household's home location <br>
# 50=0-99 <br>
# 300=100-499 <br>
# 750=500-999 <br>
# 1500=1,000-1,999 <br>
# 3000=2,000-3,999 <br>
# 7000=4,000-9,999 <br>
# 17000=10,000-24,999 <br>
# 30000=25,000-999,999

# %%
nums = [-9]
df = vehicles[~vehicles['HTEEMPDN'].isin(nums)]
sns.catplot(data=df, kind='count', x='HTEEMPDN', aspect=2)

# %% [markdown]
# HTEEMPDN - Category of workers per square mile in the census tract of the household's home location <br>
# 25=0-49 <br>
# 75=50-99 <br>
# 150=100-249 <br>
# 350=250-499 <br>
# 750=500-999 <br>
# 1500=1,000-1,999 <br>
# 3000=2,000-3,999 <br>
# 5000=4,000-999,999

# %%
nums = [-9]
df = vehicles[~vehicles['HTPPOPDN'].isin(nums)]
sns.catplot(data=df, kind='count', x='HTPPOPDN', aspect=2)

# %% [markdown]
# HTPPOPDN - Category of population density (persons per square mile) in the census tract of the household's home location <br>
# 50=0-99 <br>
# 300=100-499 <br>
# 750=500-999 <br>
# 1500=1,000-1,999 <br>
# 3000=2,000-3,999 <br>
# 7000=4,000-9,999 <br>
# 17000=10,000-24,999 <br>
# 30000=25,000-999,999

# %%
nums = [-9, -8, -7]
df = vehicles[~vehicles['HHFAMINC'].isin(nums)]
sns.catplot(data=df, kind='count', x='HHFAMINC', aspect=2)

# %% [markdown]
# HHFAMINC - Household income
# 01=Less than \\$10,000 <br>
# 02=\\$10,000 to \\$14,999 <br>
# 03=\\$15,000 to \\$24,999 <br>
# 04=\\$25,000 to \\$34,999 <br>
# 05=\\$35,000 to \\$49,999 <br>
# 06=\\$50,000 to \\$74,999 <br>
# 07=\\$75,000 to \\$99,999 <br>
# 08=\\$100,000 to \\$124,999 <br>
# 09=\\$125,000 to \\$149,999 <br>
# 10=\\$150,000 to \\$199,999 <br>
# 11=\\$200,000 or more

# %%
nums = [-9, -8, -7]
df = vehicles[~vehicles['HHSIZE'].isin(nums)]
sns.catplot(data=df, kind='count', x='HHSIZE', aspect=2)

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(data=vehicles, x='VEHTYPE', y='CNTTDHH')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_598/3662613354.py in <module>
#       1 plt.figure(figsize=(12,7))
# ----> 2 sns.scatterplot(data=vehicles, x='VEHTYPE', y='CNTTDHH')
#
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/conda/lib/python3.9/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     799
#     800     variables = _ScatterPlotter.get_semantics(locals())
# --> 801     p = _ScatterPlotter(
#     802         data=data, variables=variables,
#     803         x_bins=x_bins, y_bins=y_bins,
#
# /opt/conda/lib/python3.9/site-packages/seaborn/relational.py in __init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     585         )
#     586
# --> 587         super().__init__(data=data, variables=variables)
#     588
#     589         self.alpha = alpha
#
# /opt/conda/lib/python3.9/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# /opt/conda/lib/python3.9/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# /opt/conda/lib/python3.9/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     900
#     901                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 902                 raise ValueError(err)
#     903
#     904             else:
#
# ValueError: Could not interpret value `CNTTDHH` for parameter `y`

# %% [markdown]
# BESTMILE - Best estimate of annual miles.

# %%
hbhur = ['Town', 'Rural', 'Second City', 'Suburban', 'Urban']
vehicles['HBHUR'] = vehicles['HBHUR'].replace({'T': 'Town',
                                               'R': 'Rural',
                                               'C': 'Second City',
                                               'S': 'Suburban',
                                               'U': 'Urban'})
plt.figure(figsize=(12,7))
sns.scatterplot(data=vehicles[vehicles['HBHUR'].isin(hbhur)], x='HBHUR', y='GSYRGAL').set_title('Annual Gas Consumption by Area Classification')
# Out:
# Text(0.5, 1.0, 'Annual Gas Consumption by Area Classification')

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(data=vehicles[(vehicles['VEHYEAR'] >= 0) & (vehicles['FUELTYPE'].isin(fuel_types))], x='VEHYEAR', y='FEGEMPG', hue='FUELTYPE', palette='deep').set_title('Fuel Economy by Vehicle Year & Fuel Type')
# Out:
# Text(0.5, 1.0, 'Fuel Economy by Vehicle Year & Fuel Type')

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=vehicles[(vehicles['OD_READ'] >= 0) & (vehicles['FUELTYPE'].isin(fuel_types))], x='OD_READ', y='FEGEMPG', hue='FUELTYPE', palette="deep").set_title('Fuel Economy by Odomoter Reading & Fuel Type')
# Out:
# Text(0.5, 1.0, 'Fuel Economy by Odomoter Reading & Fuel Type')

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(data=vehicles[(vehicles['VEHYEAR'] >= 0) & (vehicles['FUELTYPE'].isin(fuel_types))], x='VEHYEAR', y='GSTOTCST', hue='FUELTYPE', palette="deep").set_title('Annual Fuel Cost by Vehicle Year & Fuel Type')
# Out:
# Text(0.5, 1.0, 'Annual Fuel Cost by Vehicle Year & Fuel Type')

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(data=vehicles, x='HTRESDN', y='HTPPOPDN', hue='VEHTYPE', palette="deep")
# Out:
# <AxesSubplot:xlabel='HTRESDN', ylabel='HTPPOPDN'>
